# %% [markdown]
# # AirSonDo_incheon
#  - 2019.01.02 01:00 부터 수집을 시작해서 모으는 DATA
#  - 모으는데로 간단한 경향 분석을 볼수 있도록 작성

# %% [markdown]
# ## Release Note ... rel.1.0 - 2019.1/3 (Thu)
# 1. 최초..

# %%
"""
* 청라, 송도지역 미세먼지 측정값 스크래핑
"""
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = os.getcwd()    # 'C:\\Users\\nitt0\\Documents\\Github\\web_beautifulsoup_scrapping\\jupyter_air'
file_name = '2019_01_air.csv'
file_name_dir = os.path.join(path, 'static', 'data', file_name)

# %%
df = pd.read_csv(file_name_dir)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 12 columns):
# Time          117 non-null object
# Unnamed: 0    117 non-null int64
# SO2           117 non-null float64
# NO2           117 non-null float64
# O3            117 non-null float64
# CO            117 non-null float64
# PM10          117 non-null int64
# PM2.5         117 non-null int64
# TIMES         117 non-null object
# CO_mod        117 non-null float64
# PM10_mod      117 non-null float64
# PM2.5_mod     117 non-null float64
# dtypes: float64(7), int64(3), object(2)
# memory usage: 11.0+ KB

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

# Major ticks every 20, minor ticks every 5
major_ticks = np.arange(0, 101, 20)
minor_ticks = np.arange(0, 101, 5)

ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)

ax.set_yticks(major_ticks)
ax.set_yticks(minor_ticks, minor=True)

ax.grid(which='both')
ax.grid(which='minor', alpha=0.4)
ax.grid(which='major', alpha=0.7)

# %%
len(df.Time)+1
# Out:
# 118

# %%
interval_list = [ n if i == 1 or i == len(df.Time) or i%12 == 0 else ' ' for i, n in enumerate(df.Time,1)]
interval_index = [item for item in interval_list if item != ' ']
interval_index
# Out:
# ['2019-01-02 1:00',
#  '2019-01-02 12:00',
#  '2019-01-03 0:00',
#  '2019-01-03 12:00',
#  '2019-01-04 0:00',
#  '2019-01-04 12:00',
#  '2019-01-05 0:00',
#  '2019-01-05 12:00',
#  '2019-01-06 0:00',
#  '2019-01-06 12:00',
#  '2019-01-06 21:00']

# %%
for col in ['PM10', 'PM2.5']:
    ax = plt.plot(df[col])

plt.xticks(df.index, interval_list, rotation=90)
plt.grid()
plt.show()

[ plt.plot(df[col]) for col in ['SO2', 'NO2', 'O3', 'CO_mod',]]
plt.xticks()
plt.show()

# %%
df.columns    

# ['Time', 'Unnamed: 0', 'SO2', 'NO2', 'O3', 'CO', 'PM10', 'PM2.5',
# 'TIMES', 'CO_mod', 'PM10_mod', 'PM2.5_mod']
# Out:
# Index(['Time', 'Unnamed: 0', 'SO2', 'NO2', 'O3', 'CO', 'PM10', 'PM2.5',
#        'TIMES', 'CO_mod', 'PM10_mod', 'PM2.5_mod'],
#       dtype='object')
